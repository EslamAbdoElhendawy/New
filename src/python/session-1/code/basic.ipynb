# %%
email = "Amit_ml@gmail.edu"

# Input Validation
if email.count("@") != 1 or "." not in email.split("@")[1]:
    print("Invalid email")
else:
    # Extract Username
    username = email.split("@")[0]

    # Extract Domain
    domain_part = email.split("@")[1]
    domain = domain_part.rsplit(".", 1)[0]

    # Check Domain Ending
    if email.endswith(".com"):
        domain_type = "Commercial Domain"
    elif email.endswith(".edu"):
        domain_type = "Educational Domain"
    else:
        domain_type = "Other Domain"

    print("Username:", username)
    print("Domain:", domain)
    print("Domain Type:", domain_type)
# Out:
# Username: Amit_ml
# Domain: gmail
# Domain Type: Educational Domain

# %%
# Encoded message
encoded_message = "###!!@mocleW EPGTQ!!!6789"

# Step 1: Extract the core part of the message: "mocleW EPGTQ"
print(encoded_message[6:18])

# Step 2: Reverse the first word: "mocleW" becomes "Welcome".
print(encoded_message.replace("mocleW","welcome"))

# Step 3: Replace shifted vowels in the second word
# (No vowels to replace in this case)
decoded_second = second_word

# Step 4: Final decoded message
decoded_message = f"{decoded_first} {decoded_second}"
print("Final decoded message:", decoded_message)
# Out:
# mocleW EPGTQ
# ###!!@welcome EPGTQ!!!6789
# Final decoded message: Welcom EPGTQ

# %%
message = "&&&**$gnirtS PLIO!!@1234"

# Extract core part
core = "".join(c for c in message if c.isalpha() or c.isspace()).strip()

word1, word2 = core.split()

# Reverse first word
decoded_word1 = word1[::-1]

# Replace shifted vowels
vowel_map = {
    "I": "E",
    "O": "U"
}

decoded_word2 = "".join(vowel_map.get(c, c) for c in word2)

print(decoded_word1, decoded_word2)
# Out:
# String PLEU

# %%
message = "##$$$@!yalpstcejorp EPUVT****9887"

# Extract core part
core = "".join(c for c in message if c.isalpha() or c.isspace()).strip()

word1, word2 = core.split()

# Reverse first word
decoded_word1 = word1[::-1]

# Replace shifted vowels
vowel_map = {
    "E": "A",
    "U": "O"
}

decoded_word2 = "".join(vowel_map.get(c, c) for c in word2)

print(decoded_word1, decoded_word2)
# Out:
# projectsplay APOVT
