# %%
#Print a message onto the screen:
print("Hello")
#If you want to print a long string (in multiple lines) put ''' at the beginning and the end of the string:
print('''
go to the bed
oben the wendow 
close the door''')
# or 
print("go to the bed\nopen the window\nclose the door")
print('mahmoud'+ 'hassan') #output: mahmoudhassan

#######################################################################################################################
# Variables 
# Python variables:
    # A variable name must start with a letter or the underscore character
    #  A variable name cannot start with a number
    # A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
    # Variable names are case-sensitive (age, Age and AGE are three differentvariables)
    # constant variables are usually written in all uppercase letters with underscores separating words
myvar = "Ahmed"
my_var = "Ahmed" #but [my-var = "Ahmed"] or [my var = "Ahmed"] are not allowed because they contain spaces or -
_my_var = "Ahmed"
myVar = "Ahmed"
MYVAR = "Ahmed" #note that [MYVAR] is different from [myVAR]
myvar2 = "Ahmed"   #but [2myvar = "Ahmed"] is not allowed because it starts with a number

first_name = "Mahmoud"
last_name = "Ali"
full_name = f"{first_name} {last_name}"              #using f string to format the string
print(first_name, last_name ) or print(full_name)     #output: Mahmoud Ali

x , y , z = 1, 2.5, "ho"   #you can assign multiple variables in one line
print(x)  #output: 1

MAX_CONNECTIONS = 5000  #When you want to treat a variable as a constant in your code, you should name it using all uppercase letters with underscores separating words
print(MAX_CONNECTIONS) #output: 5000
#######################################################################################################################
#Data Types [int, float, string, boolean]
x = 5           #integer  #You can use some basic mathematical operations with print()  like + - * / #print(5+3) output: 8
y = 3.14        #float    #when you divide two integers you get a float number like print(4/2) output: 2.0
name = 'Ahmed'  #string   #note you can use single or double quotes around [""] [''] 
is_student = True  #boolean

#########################################################################################################################
#List
names = ['mahmoud', 'ali', 'ahmed', 'Eslam']
print(names[0])  #output: mahmoud
print(names[1])  #output: ali
print(names[-2])  #output: ahmed

#Changing, appending, Inserting, and Removing , Extending , Elements in a List
names[1] = 'hassan'  #changing the value at index 1
print(names)  #output: ['mahmoud', 'hassan', 'ahmed', 'Eslam']

names.append('sara')  #adding an element to the end of the list
print(names)  #output: ['mahmoud', 'hassan', 'ahmed', 'Eslam', 'sara']

names.insert(2, 'khaled')  #inserting an element at index 2
print(names)  #output: ['mahmoud', 'hassan', 'khaled', 'ahmed', 'Eslam', 'sara']

names.remove('ahmed')  #removing an element from the list
print(names)  #output: ['mahmoud', 'hassan', 'Eslam', 'sara']

more_names = ['omar', 'youssef']
names.extend(more_names)  #extending the list by adding elements from another list
print(names)  #output: ['mahmoud', 'hassan', 'Eslam', 'sara', 'omar', 'youssef']
#########################################################################################################################
#Removing by del statement , pop() method , clear() method 
del names[3]  #removing the element at index 3
print(names)  #output: ['mahmoud', 'hassan', 'Eslam', 'omar', 'youssef'] note that 'sara' is removed

popped_name = names.pop()  #removing and returning the last element of the list
print(popped_name)  or print(names.pop()) 
print(names)  #output: ['mahmoud', 'hassan', 'Eslam', 'omar', 'youssef'] note that 'youssef' is removed
names.pop(2)  #removing the element at index 2
print(names)  #output: ['mahmoud', 'hassan', 'Eslam', 'omar']

names.clear()  #removing all elements from the list
print(names)  #output: []
#########################################################################################################################
#Organizing a List [Sorting , Reversing]
numbers = [3, 1, 4, 2 , 10]
numbers.sort()  #sorting the list in ascending order
print(numbers)  #output: [1, 2, 3, 4, 10]   
numbers.reverse()  #sorting the list in descending order
print(numbers)  #output: [10, 4, 3, 2, 1]
#########################################################################################################################
#List Length
print(len(numbers))    #output: 5
#########################################################################################################################
#looping Through a List
for name in more_names:
    print(name)  #output: omar
                 #        yousssef
#########################################################################################################################
#Statistics with a List of Numbers
stats = [10, 20, 30, 40, 50]
print(min(stats))   #output: 10
print(max(stats))   #output: 50
print(sum(stats))   #output: 150
print(sum(stats) / len(stats))  #output: 30.0  #calculating the average
#########################################################################################################################
#List Comprehensions تراكيب القائمة
squares = [x**2 for x in range(1, 6)]  #creating a list of squares from 1 to 5
print(squares)  #output: [1, 4, 9, 16, 25]
even_squares = [x**2 for x in range(1, 11) if x % 2 == 0]  #creating a list of squares of even numbers from 1 to 10
print(even_squares)  #output: [4, 16, 36, 64, 100]
#########################################################################################################################
# exercises
# 3.1 Guest List
guests = ["Albert Einstein", "Marie Curie", "Nelson Mandela"]

print("=== Invitations (3.1) ===")
for guest in guests:
    print(f"Dear {guest}, you are invited to dinner. Please join us!")

# Output:
# === Invitations (3.1) ===
# Dear Albert Einstein, you are invited to dinner. Please join us!
# Dear Marie Curie, you are invited to dinner. Please join us!
# Dear Nelson Mandela, you are invited to dinner. Please join us!


# 3.2 Changing Guest List
cant_make_it = guests[1]  # Marie Curie can't make it
print(f"\nUnfortunately, {cant_make_it} can't make it to the dinner.")

# Output:
# Unfortunately, Marie Curie can't make it to the dinner.

# Replace the guest who can't make it
guests[1] = "Leonardo da Vinci"

print("\n=== Updated Invitations (3.2) ===")
for guest in guests:
    print(f"Dear {guest}, you are invited to dinner. Please join us!")

# Output:
# === Updated Invitations (3.2) ===
# Dear Albert Einstein, you are invited to dinner. Please join us!
# Dear Leonardo da Vinci, you are invited to dinner. Please join us!
# Dear Nelson Mandela, you are invited to dinner. Please join us!


# 3.3 More Guests
print("\nGood news! I found a bigger dinner table, so more guests can be invited.")

# Output:
# Good news! I found a bigger dinner table, so more guests can be invited.

# Add more guests
guests.insert(0, "Isaac Newton")              # Beginning
guests.insert(len(guests) // 2, "Cleopatra")  # Middle
guests.append("Nikola Tesla")                 # End

print("\n=== Final Invitations (3.3) ===")
for guest in guests:
    print(f"Dear {guest}, you are invited to dinner. Please join us!")

# Output:
# === Final Invitations (3.3) ===
# Dear Isaac Newton, you are invited to dinner. Please join us!
# Dear Albert Einstein, you are invited to dinner. Please join us!
# Dear Cleopatra, you are invited to dinner. Please join us!
# Dear Leonardo da Vinci, you are invited to dinner. Please join us!
# Dear Nelson Mandela, you are invited to dinner. Please join us!
# Dear Nikola Tesla, you are invited to dinner. Please join us!
###########################################################################################################################
#Slicing a List تقسيم القائمة   - Looping Through a Slice التكرارمن خلال جزء من القائمة
names = ['mahmoud', 'hassan', 'khaled', 'ahmed', 'Eslam', 'sara', 'omar', 'youssef']
print(names[1:4])    #output: ['hassan', 'khaled', 'ahmed']
print(names[:3])     #output: ['mahmoud', 'hassan', 'khaled']
print(names[4:])     #output: ['Eslam', 'sara', 'omar', 'youssef']
print(names[-3:])    #output: ['sara', 'omar', 'youssef']
print(names[:-4])    #output: ['mahmoud', 'hassan', 'khaled', 'ahmed']
print(names[-5:-2])  #output: ['ahmed', 'Eslam', 'sara']    
for name in names[2:5]:
    print(name)  #output: khaled
                 #        ahmed
                 #        Eslam
#########################################################################################################################
#Copying a List نسخ قائمة
original_names = ['mahmoud', 'hassan', 'khaled']
copied_names = original_names[:]  #copying the entire list
print(copied_names)  #output: ['mahmoud', 'hassan', 'khaled']
#########################################################################################################################
#Tuples - Immutable Lists  قوائم غير قابلة للتغيير اى لا يمكن اضافة او حذف او تعديل عناصرها
coordinates = (10, 20)  #creating a tuple
print(coordinates[0])  #output: 10
print(coordinates[1])  #output: 20
#coordinates[0] = 15  #this will raise an error because tuples are immutable
print(coordinates)  #output: (10, 20)
#You can unpack a tuple into variables
x, y = coordinates
print(x)  #output: 10
print(y)  #output: 20
#########################################################################################################################
#dictionaries - Key-Value Pairs  القواميس - أزواج المفتاح والقيمة
person = {                 #creating a dictionary key:value pairs you can use {} or dict()       
    "name": "Ahmed",
    "age": 25,
    "city": "Cairo"
}
print(person["name"])  #output: Ahmed
print(person["age"])   #output: 25
print(person["city"])  #output: Cairo

#Modifying , Adding , and Removing Key-Value Pairs in a Dictionary
person["age"] = 26     #changing the value of a key
print(person["age"])   #output: 26
person["job"] = "Engineer"  #adding a new key-value pair
print(person["job"])       #output: Engineer
del person["city"]        #removing a key-value pair
print(person)  #output: {'name': 'Ahmed', 'age': 26, 'job': 'Engineer'}
#looping Through a Dictionary
for key, value in person.items():
    print(f"{key}: {value}")
         #output: name: Ahmed
         #        age: 26
         #        job: Engineer
#########################################################################################################################
# if Statements و بيانات الشرط
age = 20
if age < 18:
    print("You are a minor.")   #output: You are a minor.
else:
    print("You are an adult.")   #output: You are an adult.
#Elif statements
score = 85
if score >= 90:
    print("Grade: A")   #output: Grade: A
elif score >= 80:
    print("Grade: B")   #output: Grade: B
elif score >= 70:
    print("Grade: C")  #output: Grade: C
else:
    print("Grade: F")  #output: Grade: F
#########################################################################################################################
#f strings  سلاسل التنسيق
name = "Ahmed"
age = 25
print(f"My name is {name} and I am {age} years old.")  #output: My name is Ahmed and I am 25 years old.
#########################################################################################################################
#input() Function دالة الإدخال
name = input("Enter your name: ")  #prompting the user to enter their name
print(f"Hello, {name}!")  #output: Hello, [name]!
age = int(input("Enter your age: "))  #prompting the user to enter their age and converting it to an integer
print(f"You are {age} years old.")  #output: You are [age] years old.
#########################################################################################################################
#while Loops الحلقات التكرارية
count = 0
while count < 5:
    print(f"Count: {count}")  #output: Count: 0
                              #        Count: 1
                              #        Count: 2
                              #        Count: 3
                              #        Count: 4
    count += 1
#########################################################################################################################
#continue and break statements  استمر و اكسر البيانات
for num in range(1, 11):
    if num % 2 == 0:             
        continue  #skip even numbers
    if num > 7:
        break     #stop the loop if num is greater than 7
    print(num)    #output: 1
                  #        3
                  #        5
                  #        7
#########################################################################################################################
#Function Functions الدوال
def greet(name):             #that means we are defining a function called greet that takes one parameter called name
    print(f"Hello, {name}!")  #output: Hello, [name]!
greet("Ahmed")  #calling the function with argument "Ahmed"
greet("Sara")   #calling the function with argument "Sara"

def add(a, b):
    return a + b  #returning the sum of a and b
result = add(5, 3)  #calling the function with arguments 5 and 3
print(result)  #output: 8
#########################################################################################################################
# Out:
# Hello
#
# go to the bed
# oben the wendow
# close the door
# go to the bed
# open the window
# close the door
# mahmoudhassan
# Mahmoud Ali
# Mahmoud Ali
# 1
# 5000
# mahmoud
# ali
# ahmed
# ['mahmoud', 'hassan', 'ahmed', 'Eslam']
# ['mahmoud', 'hassan', 'ahmed', 'Eslam', 'sara']
# ['mahmoud', 'hassan', 'khaled', 'ahmed', 'Eslam', 'sara']
# ['mahmoud', 'hassan', 'khaled', 'Eslam', 'sara']
# ['mahmoud', 'hassan', 'khaled', 'Eslam', 'sara', 'omar', 'youssef']
# ['mahmoud', 'hassan', 'khaled', 'sara', 'omar', 'youssef']
# youssef
# omar
# ['mahmoud', 'hassan', 'khaled', 'sara']
# ['mahmoud', 'hassan', 'sara']
# []
# [1, 2, 3, 4, 10]
# [10, 4, 3, 2, 1]
# 5
# omar
# youssef
# 10
# 50
# 150
# 30.0
# [1, 4, 9, 16, 25]
# [4, 16, 36, 64, 100]
# === Invitations (3.1) ===
# Dear Albert Einstein, you are invited to dinner. Please join us!
# Dear Marie Curie, you are invited to dinner. Please join us!
# Dear Nelson Mandela, you are invited to dinner. Please join us!
#
# ...
